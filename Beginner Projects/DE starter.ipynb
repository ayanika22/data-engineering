# %%
# !pip install psycopg2
# Out:
# ...
#      ---------------------------------------- 1.2/1.2 MB 3.7 MB/s eta 0:00:00
# ...

# %%
import psycopg2 as psy 
import pandas as pd

# %% [markdown]
# ## Create A Database

# %%
def create_db():
    #create default database
    conn = psy.connect("host=localhost dbname=postgres user=postgres password=root")
    conn.set_session(autocommit=True)
    cur=conn.cursor()
    
    cur.execute("drop database if exists users")
    cur.execute("create database users")
    
    #close connection
    conn.close()
    
    conn = psy.connect("host=localhost dbname=users user=postgres password=root")
    conn.set_session(autocommit=True)
    cur=conn.cursor()
    
    return cur,conn

# %% [markdown]
# ### Import and Clean Datasets

# %%
url_path_0 = "https://drive.google.com/uc?id=1tAJd1Piu9ZSDis12WfJ8oU4CiB2F19zy"
ac_country = pd.read_csv(url_path_0)
ac_country.head()
# Out:
#   Code                  Long Name         Income Group  \
# 0  ALB        Republic of Albania  Upper middle income
# 1  ARG         Argentine Republic  Upper middle income
# 2  ARM        Republic of Armenia  Upper middle income
# 3  AUS  Commonwealth of Australia          High income
# 4  AUT        Republic of Austria          High income
#
#                       Region Lending category Other groups      Currency Unit  \
# 0      Europe & Central Asia             IBRD          NaN       Albanian lek
# 1  Latin America & Caribbean             IBRD          NaN     Argentine peso
# 2      Europe & Central Asia             IBRD          NaN      Armenian dram
# 3        East Asia & Pacific              NaN          NaN  Australian dollar
# 4      Europe & Central Asia              NaN    Euro area               Euro
#
#                             Latest population census  \
# 0                                    2020 (expected)
# 1                                    2020 (expected)
# ...

# %%
ac_country_clean = ac_country[['Code','Long Name','Region','Table Name','Short Name']]
ac_country_clean.head()
# Out:
#   Code                  Long Name                     Region Table Name  \
# 0  ALB        Republic of Albania      Europe & Central Asia    Albania
# 1  ARG         Argentine Republic  Latin America & Caribbean  Argentina
# 2  ARM        Republic of Armenia      Europe & Central Asia    Armenia
# 3  AUS  Commonwealth of Australia        East Asia & Pacific  Australia
# 4  AUT        Republic of Austria      Europe & Central Asia    Austria
#
#   Short Name
# 0    Albania
# 1  Argentina
# 2    Armenia
# 3  Australia
# 4    Austria

# %%
url_path = "https://drive.google.com/uc?id=1E3M0j63FhC0bsQ4Wm59WiOOAU_lgtPvt"
ac_data = pd.read_csv(url_path)
ac_data.head()
# Out:
#              Code                                     Indicator Name  \
# 0       NW.HCA.TO                  Human capital (constant 2018 US$)
# 1       NW.HCA.PC       Human capital per capita (constant 2018 US$)
# 2  NW.HCA.FEMP.PC  Human capital per capita, employed female (con...
# 3  NW.HCA.MEMP.PC  Human capital per capita, employed male (const...
# 4  NW.HCA.FEMA.PC  Human capital per capita, female (constant 201...
#
#                                      Long definition  \
# 0  Human capital is computed as the present value...
# 1  Human capital is computed as the present value...
# 2  Human capital is computed as the present value...
# 3  Human capital is computed as the present value...
# 4  Human capital is computed as the present value...
#
#                                               Source          Topic  \
# 0  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 1  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# ...

# %%
ac_data.columns
ac_data_clean = ac_data.loc[:,['Code', 'Topic', 'Indicator Name']]

# %%
url_path_2 = "https://drive.google.com/uc?id=1VeykgbX_6ejqu-UuBaOcTD4TjXCQxgE3"
ac_series = pd.read_csv(url_path_2)
ac_series.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code  \
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC
#
#   1995 [YR1995] 1996 [YR1996] 1997 [YR1997] 1998 [YR1998] 1999 [YR1999]  \
# 0      4.49E+10      4.34E+10      3.71E+10      3.88E+10      4.22E+10
# 1      14072.79      13708.99       11794.1      12399.48      13573.26
# 2      3468.858      3355.549      2868.997      3013.391      3259.893
# 3      6507.931      6353.737      5466.692      5901.072       6492.73
# ...

# %%
ac_series_clean = ac_series.loc[:,['Country Name','Country Code','Series Code', '1995 [YR1995]','1996 [YR1996]', '1997 [YR1997]','1998 [YR1998]','1999 [YR1999]','2000 [YR2000]']]

# %%
cur, conn = create_db()

# %% [markdown]
# ### Create Tables

# %%
ac_country_table_create = ("""CREATE TABLE IF NOT EXISTS ac_country(
country_code varchar primary key,
name varchar,
region varchar,
table_name varchar,
short_name varchar
)""")

# %%
cur.execute(ac_country_table_create)
conn.commit()

# %%
ac_data_table_create = ("""CREATE TABLE IF NOT EXISTS ac_data(
code varchar primary key,
topic varchar,
indicator_name varchar
)""")

# %%
cur.execute(ac_data_table_create)
conn.commit()

# %%
ac_series_table_create = ("""CREATE TABLE IF NOT EXISTS ac_series(
country_name varchar,
country_code varchar primary key,
series_code varchar,
Y1995 varchar,
Y1996 varchar,
Y1997 varchar,
Y1998 varchar,
Y1999 varchar,
Y2000 varchar
)""")

# %%
cur.execute(ac_series_table_create)
conn.commit()

# %% [markdown]
# ### Create Insert Queries

# %%
ac_country_table_insert = """
    INSERT INTO ac_country (
        country_code,
        name,
        region,
        table_name,
        short_name
    )
    VALUES (%s, %s, %s, %s, %s) 
    ON CONFLICT (country_code) DO NOTHING
"""

# %%
ac_data_table_insert = """
    INSERT INTO ac_data (code, topic, indicator_name)
    VALUES (%s, %s, %s)
    ON CONFLICT (code) DO NOTHING
"""

# %%
ac_series_table_insert = """
    INSERT INTO ac_series (
    country_name, 
    country_code, 
    series_code, 
    Y1995, Y1996, Y1997, Y1998, Y1999, Y2000)
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)
    ON CONFLICT (country_code) DO NOTHING
"""

# %% [markdown]
# ### Insert data into tables

# %%
for i, row in ac_country_clean.iterrows():
    cur.execute(ac_country_table_insert,list(row))

# %%
for i, row in ac_data_clean.iterrows():
    cur.execute(ac_data_table_insert,list(row))

# %%
for i, row in ac_series_clean.iterrows():
    cur.execute(ac_series_table_insert,list(row))

# %% [markdown]
# ### Commit and Close Connection

# %%
conn.commit()

# %%
conn.close()
